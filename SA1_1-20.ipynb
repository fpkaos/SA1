# %% [markdown]
# ## Список вопросов к экзамену
#
# 1. Определение информации и автоматизированной системы обработки информации
# 2. Объекты АС, субъекты АС, ИБ АС
# 3. Актив, информационный актив, объект среды информационного актива
# 4. Базовые свойства защищаемой информации КЦД
# 5. Методы обеспечения ИБ
# 6. Событие ИБ, инцидент ИБ, менеджмент инцидентов ИБ
# 7. Уязвимость ИБ, угроза, угроза ИБ
# 8. Реализация угрозы ИБ
# 9. Классификация угроз ИБ
# 10. Инвентаризация ИА: основные этапы, перечень ИА
# 11. Владелец информационного актива, пользователь ИА, формат ИА, группа ИА
# 12. Выявление (идентификация) ИА, схема ИА
# 13. Классификация ИА, описание объектов среды ИА, тип, размещение ИА
# 1.	Классификация иа - положительные эффекты
# 2.	Модель угроз (безопасности информации), основные направления использования му
# 3.	Нарушитель, модель нарушителя, типы нарушителей,
# 4.	Нарушитель, потенциал нарушителя, сговор нарушителей, доверенный пользователь
# 5.	Определение актуальных угроз, вероятностью реализации угрозы иб, проектная защищенность ис, уровень проектной защищенности
# 6.	Степень возможного ущерба- оценка
# 7.	Непосредственное воздействие, опосредованное воздействие
# 8.	Виды ущерба: социальный, ущерб субъекту персональных данных
# 9.	Политический, технологический, репутационный
# 10.	Определение актуальности угрозы
# 11.	Примерная структура модели угроз
# 12.	Риск иб, риск нарушения иб
# 13.	Анализ рисков иб, идентификация рисков иб
# 14.	Количественная оценка или установление значения рисков иб, оценивание риска иб, обработка рисков иб
# 15.	Управление рисками иб
# 16.	Задачи управления рисками иб
# 17.	Подходы к управлению рисками иб
# 18.	Процесс управления рисками иб
# 19.	Системный подход к управлению рисками иб
# 20.	Структура управления рисками иб
# 21.	Модель pdca для управления рисками иб
# 22.	Оценка рисков иб, основные этапы
# 23.	Анализ рисков иб (идентификация рисков иб)
# 24.	Анализ рисков иб (идентификация средств управления рисками иб)
# 25.	Анализ рисков иб (идентификация уязвимостей)
# 26.	Классификация уязвимостей- по причинам возникновения, по месту нахождения
# 27.	Классификация уязвимостей, по степени критичности (уровню риска), по вероятности реализации
# 28.	Анализ рисков иб (идентификация последствий), типы
# 29.	Количественная оценка рисков иб
# 30.	Качественный подход к количественной оценке
# 31.	Количественный подход к количественной оценке
# 32.	Комбинированный полуколичественный подход к количественной оценке
# 33.	Оценка последствий
# 34.	Оценка последствий (оценка активов организации)
# 35.	Оценка вероятностей
# 36.	Оценка вероятностей, факторы
# 37.	Определение уровня (величины) рисков иб, размер ущерба
# 38.	Вычисление ale
# 39.	Оценивание рисков иб
# 40.	Подходы к оценке рисков иб
# 41.	Подходы к оценке рисков иб – базовый анализ рисков иб
# 42.	Подходы к оценке рисков иб – неформальный анализ
# Рисков иб
# 43.	Подходы к оценке рисков иб – детальный анализ рисков иб
# 44.	Подходы к оценке рисков иб – комбинированный анализ рисков иб
# 45.	Подходы к оценке рисков иб – высокоуровневая оценка рисков иб
# 46.	Статистический подход
# 47.	Многофакторный подход
# 48.	Подход с помощью разграничений
# 49.	Обработка рисков иб-цель обработки рисков иб
# 50.	Снижение риска иб
# 51.	Сохранение риска иб
# 52.	Избежание риска иб
# 53.	Передача риска иб
# 54.	Принятие рисков иб
# 55.	Коммуникация рисков иб
# 56.	Мониторинг и пересмотр рисков иб
# 57.	Документальное обеспечение управления рисками иб
# 58.	Модель документов по иб в соотв. С рс бр иббс-2.0-2007
# 59.	Общая политика иб
# 60.	Частные политики иб
# 61.	3 уровень документации
# 62.	4 уровень документации
# 63.	Определение аудита, аудита иб
# 64.	Фундаментальные основы аудита иб
# 65.	Деятельность по оценке информационной безопасности, контекст оценки иб, критерии оценки иб, модель оценки иб
# 66.	Свидетельства оценки иб, результаты оценки иб
# 67.	Виды оценки информационной безопасности
# 68.	Оценка соответствия информационной безопасности организации установленным требованиям
# 69.	Этапы оценки соответствия иб
# 70.	Риск-ориентированная оценка иб
# 71.	Присущий (неотъемлемый) риск
# 72.	Оценка иб на основе экономических показателей
# 73.	Цели оценки соответствия иб организации
# 74.	Значение аудита информационной безопасности
# 75.	Принципы аудита иб
# 76.	Требования к этапам проведения аудита
# 77.	Подготовка к проведению аудита
# 78.	План аудита
# 79.	Программа аудита иб
# 80.	Анализ документации
# 81.	Проведение аудита на месте
# 82.	Анализ данных и подготовка отчета
# 83.	Заключительные действия по результатам аудита
# 84.	Реагирование или реакция на компьютерные инциденты
# 85.	Реагирование на инциденты- основные процедуры
# 86.	Подготовка к инциденту
# 87.	Запись криптографических контрольных (хэш) сумм для важных файлов
# 88.	Усиление или разрешение регистрации аудита безопасности
# 89.	Резервное копирование критически важных данных
# 90.	Виды резервного копирования
# 91.	Обучение пользователей защите на уровне хостов
# 92.	Подготовка сети
# 93.	Установка брандмауэров и систем выявления вторжений
# 94.	Использование списков управления доступом в маршрутизаторах
# 95.	Использование протокола сетевого времени
# 96.	Создание сетевой топологии, помогающей проводить мониторинг
# 97.	Шифрование сетевого трафика
# 98.	Координация действий с вышестоящими организациями, участвующими в инциденте
# 99.	Формирование команды реагирования на инциденты
# 100.	Проведение первичной оценки инцидента
# 101.	Анализ сетевой топологии
# 102.	Проверка политик
# 103.	Исследование инцидента
# 104.	Формулировка стратегии реагирования- стратегия реагирования
# 105.	Восстановление рабочих операций
# 106.	Сравнение реагирования в интерактивном и автономном режимах
# 107.	Общественный резонанс
# 108.	Выявление атакующего
# 109.	Определение типа атаки
# 110.	Классификация системы-жертвы
# 111.	Компьютерный судебный процесс, информационная среда доказательства, целевая информационная среда, восстановленный образ, собственная операционная система
# 112.	Прямой анализ, автономный анализ
# 113.	Сбор доказательств (ошибки начинающего исследователя)
# 114.	Обычные ошибки при получении доказательств
# 115.	Технические ошибки при получении доказательств
# 116.	Порядок хранения
# 117.	Карточка доказательства
# 118.	Выполнение начального реагирования
# 119.	Выполнение судебного дублирования
# 120.	Подходы к судебному дублированию
# 121.	Проверка низкоуровневой конфигурации системы
# 122.	Определение геометрии диска
# 123.	Определение последовательности начальной загрузки
# 124.	Выполнение судебного анализа
# 125.	Выполнение физического анализа
# 126.	Выполнение поиска и извлечения
# 127.	Извлечение файлового зазора и свободного пространства
# 128.	Определение места доказательства

# %% [markdown]
# ## 1. Определение информации и автоматизированной системы обработки информации
#
# Юридическое определение:
#
# **Информация** – сведения (сообщения, данные) независимо от формы их представления ([Федеральный закон от 27 июля 2006 года № 149-ФЗ «Об информации, информационных технологиях и о защите информации»](http://www.consultant.ru/document/cons_doc_LAW_61798/))
#
# Определение в информатике:
#
# **Информация** – все, что может быть представлено в символах конечного (например, бинарного) алфавита
#
# **Автоматизированная система обработки информации (АС)** - это совокупность следующих объектов:
# 1. средства вычислительной техники;
# 2. программное обеспечение;
# 3. каналы связи;
# 4. информация на различных носителях;
# 5. персонал и пользователи системы.
#
# ![](sa1_media/АС.png)

# %% [markdown]
# ## 2. Объекты АС, субъекты АС, ИБ АС
#
# **Объекты АС** – _пассивные_ компоненты системы, хранящие, принимающие или передающие информацию. Доступ к объекту означает доступ к содержащейся в нем информации.
#
# **Субъекты АС** – активные компоненты системы, которые могут быть _причиной потока информации_ от объекта к субъекту или _изменения состояния системы_. В качестве субъектов можно рассматривать пользователей, активные программы, процессы и т.д.
#
# ![](sa1_media/subj.png)
#
# **Информационная безопасность АС** - это _состояние_ системы, при котором:
# 1. Система способна противостоять дестабилизирующему воздействию внутренних и внешних угроз.
# 2. Функционирование и сам факт наличия системы не создают угроз для внешней среды и для элементов самой системы.

# %% [markdown]
# ## 3. Актив, информационный актив, объект среды информационного актива
#
# **Актив** – все, что имеет ценность для организации и находится в ее распоряжении.
#
# **Информационный актив** – _информация с реквизитами_ (данные, которые должны содержаться в акте или ином документе - чеке, векселе - для признания его действительным, например, название документа, сумма, подлежащая оплате, наименование плательщика), _позволяющими ее идентифицировать_ ; имеющая ценность для организации; находящаяся в распоряжении организации и представленная на любом материальном носителе в пригодной для ее обработки, хранения или передачи форме.
#
# **Объект среды информационного актива** – _материальный объект среды использования и (или) эксплуатации информационного актива (объект хранения, передачи, обработки, уничтожения и т.д.)_
#
# \*курсивом выделены термины из ["Рекомендации в области стандартизации Банка России "Обеспечение информационной безопасности организаций банковской системы Российской Федерации. Методика оценки рисков нарушения информационной безопасности" РС БР ИББС-2.2-2009" (приняты и введены в действие Распоряжением Банка России от 11.11.2009 N Р-1190)](http://www.consultant.ru/document/cons_doc_LAW_94789/)

# %% [markdown]
# ## 4. Базовые свойства защищаемой информации (КЦД)
#
# **Базовые свойства защищаемой информации**:
#
#  − *конфиденциальность*, означающая, что доступ к информации могут получить только легальные пользователи;
#
#  − *целостность*, обеспечивающая, что во-первых, защищаемая информация может быть изменена только законными и имеющими соответствующие полномочия пользователями, а во-вторых, информация внутренне непротиворечива и (если данное свойство применимо) отражает реальное положение вещей;
#
#  − *доступность*, гарантирующая беспрепятственный доступ к защищаемой информации для законных пользователей.

# %% [markdown]
# ## 5. Методы обеспечения ИБ
#
# 1. **Сервисы информационной безопасности**:
#     - _Идентификация_ (присвоение субъектам и объектам доступа личного идентификатора и сравнение его с заданным перечнем) и аутентификация (проверка принадлежности субъекту доступа предъявленного им идентификатора)
#     - _Разграничение доступа_ (установление полномочий - списком ресурсов, доступных пользователю, и правами по доступу к каждому ресурсу)
#     - _Протоколирование и аудит_ (Под протоколированием понимается сбор и накопление информации о событиях, происходящих в ИС. Аудит – это анализ накопленной информации, проводимый в реальном времени или периодически)
#     - Средства защиты периметра
#     - Криптографические средства защиты
#
#     ![](sa1_media/ibservices.png)
# 2. **Правовые методы**:
#     - Установление ответственности
#     - Работа с тайнами
#     - Защита авторских прав
#     - Лицензирование и сертификация
#
#     ![](sa1_media/right_asp.png)
# 3. **Теоретические методы**:
#     - Формализация процессов, связанных обеспечением ИБ - **построение моделей**
#     - Обоснование корректности и адекватности систем обеспечения ИБ - **доказательство**
# 4. **Инженерно-технические методы**:
#     - Защита информации от утечки по техническим каналам
# 5. **Организационные методы**:
#     - Управление ИБ

# %% [markdown]
# ## 6. Событие ИБ, инцидент ИБ, менеджмент инцидентов ИБ
#
# **Событие ИБ** – идентифицированное появление определенного состояния системы, сервиса или сети, указывающего на возможное _нарушение политики ИБ_ или _отказ защитных мер_ , или возникновение неизвестной ранее ситуации, которая _может иметь_ отношение к ИБ
#
# **Инцидент ИБ** – событие, являющееся следствием одного или нескольких _нежелательных или неожиданных событий ИБ_ , имеющих значительную вероятность компрометации бизнес-операции и создания угрозы ИБ.
#
# **Менеджмент инцидентов ИБ** – деятельность по своевременному обнаружению инцидентов ИБ, адекватному и оперативному реагированию на них в интересах минимизации и/или ликвидации негативных последствий для организации (включая нарушение непрерывности процессов) при нарушениях ИБ.
#
# **Мониторинг инцидентов ИБ** – деятельность направленная на выявление и идентификацию инцидентов ИБ.

# %% [markdown]
# ##  7. Уязвимость ИБ, угроза, угроза ИБ
#
# **Уязвимость ИБ** – слабое место в инфраструктуре организации, включая систему обеспечения информационной безопасности (СОИБ), которое может быть использовано для реализации или способствовать реализации угрозы ИБ.
#
# **Угроза** (threat) – это _потенциальная причина_ инцидента, который может нанести ущерб системе или организации ([ГОСТ Р ИСО/МЭК 13335-1-2006](http://docs.cntd.ru/document/1200048398))
#
# **Угроза ИБ** – угроза нарушения свойств ИБ: доступности, целостности или конфиденциальности информационных активов организации.
#
# **Угроза ИБ АС** – это возможность реализации воздействия на информацию, обрабатываемую в АС, приводящего к нарушению конфиденциальности, целостности или доступности этой информации, а также возможность воздействия на компоненты АС, приводящего к их утрате, уничтожению или сбою функционирования.

# %% [markdown]
# ## 8. Реализация угрозы ИБ
#
# **Реализация угрозы ИБ** осуществляется через наступление одного или нескольких взаимосвязанных событий и инцидентов ИБ, которые связаны с реализацией угрозы в отношении активов организации. Это приводит к нарушению свойств ИБ (целостность, доступность, конфиденциальность и др.) информационных активов организации и в последствии к негативным событиям, которые могут серьезно повлиять на достижение целей самой организации.

# %% [markdown]
# ## 9. Классификация угроз ИБ
#
# 1. **По природе возникновения**:
#     - Естественные угрозы
#     - Искусственные угрозы
# 2. **По степени преднамеренности**:
#     - Случайные угрозы
#     - Преднамеренные угрозы
# 3. **По источнику угрозы**:
#     - Природные
#     - Антропогенные
#     - От санкционированного ПО
#     - От несанкционированного ПО
# 4. **По положению источника угрозы**:
#     - Вне контролируемой зоны
#     - В пределах контролируемой зоны
# 5. **По степени воздействия на АС**:
#     - Пассивные угрозы
#     - Активные угрозы
# 6. **По способу доступа к ресурсам АС**:
#     - Использующие стандартный доступ
#     - Использующие нестандартный путь доступа
# 7. **По КЦД**:
#     - **Угрозы нарушения конфиденциальности информации** – в результате реализации информация становится доступной субъекту, не располагающему полномочиями для ознакомления с ней
#     - **Угрозы нарушения целостности информации** – любое злонамеренное искажение информации, обрабатываемой с использованием АС
#     - **Угрозы нарушения доступности информации** – возникают в тех случаях, когда доступ к некоторому ресурсу АС для легальных пользователей блокируется

# %% [markdown]
# ## 10. Инвентаризация ИА: основные этапы, перечень ИА
#
# **Система информационной безопасности (СИБ)** – совокупность защитных мер, защитных средств и процессов их эксплуатации, включая ресурсное и административное (организационное) обеспечение.
#
# **Система менеджмента информационной безопасности (СМИБ)** – часть менеджмента организации, предназначенная для создания, реализации, эксплуатации, мониторинга, анализа, поддержки и совершенствования системы обеспечения ИБ.
#
# **Система обеспечения информационной безопасности (СОИБ)** – совокупность СИБ и СМИБ организации.
#
# **Инвентаризация ИА** — составление списка (перечня) ИА, т. е. объектов, которые будут подлежать защите, и субъектов, которые задействованы в данном информационном пространстве и будут влиять на информационную защиту системы.
#
# ### Построение СИБ (инвентаризация ИА)
#
# 1. **Выявление ИА**, циркулирующих между подразделениями организации (input/output):
#    - Какая информация, в каком виде и от каких подразделений приходит?
#    - Какая информация, в каком виде и в какие подразделения уходит?
#     ![](sa1_media/inventia.png)
#
# **Перечень ИА** — _неструктурированный_ список ИА организации с указанием **владельца ИА** и **пользователей ИА**
#
# 2. **Классификация ИА** – разделение существующих информационных активов организации по типам (подмножествам), выполняемое в соответствии со степенью тяжести последствий от потери их значимых свойств ИБ.

# %% [markdown]
# ## 11. Владелец ИА, пользователь ИА, формат ИА, группа ИА
#
# **Владелец информационного актива** – лицо или структурное подразделение, которое имеет утвержденные руководством обязательства по контролю за производством, разработкой, поддержкой, использованием и безопасностью информационного актива.
#
# **Пользователь информационного актива** – лицо или структурное подразделение, использующее информационный актив для выполнения своих должностных обязанностей и поставленных задач в рамках прав доступа к информационному активу, определенных Владельцем данного информационного актива
#
# **Формат информационного актива** – представление информационного актива (бумажный или электронный формат)
#
# **Группа информационных активов** – информационные активы, объединенные по общему признаку (платежные документы, лицензии на программное обеспечение, лицензии на шифровальные средства и т.д.)

# %% [markdown]
# ## 12. Выявление (идентификация) ИА, схема ИА
#
# Конкретизация ИА до отдельных экземпляров не обязательна.
#
# Целесообразно осуществлять группировку (например, заявки на тендер, счета фактуры, договора аренды, договора закупки итд).
#
# Консультации с подразделениями по оптимальной группировке. Совместно с бизнес-подразделениями предварительно определяется важность ИА по характеристикам (целостность, конфиденциальность, доступность и др.)
#
# ![](sa1_media/schia.jpg)

# %% [markdown]
# ## 13. Классификация ИА, описание объектов среды ИА, тип ИА, размещение ИА
#
# [Классификация ИА](https://ipiskunov.blogspot.com/2016/07/blog-post_0.html)
#
# **Описание объектов среды ИА** – описание каналов передачи ИА, средств размещения и способов передачи.
#
# **Тип информационного актива** – категория информационных активов, к которой относится определенный информационный актив в соответствии с требованиями действующего [законодательства Российской Федерации](http://www.consultant.ru/document/cons_doc_LAW_48699/)
#
# **Размещение ИА** – физическое и/или логическое местонахождение информационного актива в зависимости от его формата (помещение, сейф, логический диск, файловое хранилище)
#
# ![](sa1_media/tabia.jpg)

# %% [markdown]
# ## 14. Классификация ИА - положительные эффекты
#
# **Оптимизация бизнес-процессов** – снижение времени выполнения задач, перераспределение нагрузки на сотрудников и подразделения и.т.д.
#
# **Построение эффективной схемы непрерывности бизнеса**. После проведения классификации выявляются наиболее критичные ИА для организации, а какие могут деградировать без существенного снижения качества основных бизнес-процессов.
#
# ![](sa1_media/biz.jpg)
#
# Оценка рисков, грамотное планирование затрат на обеспечение безопасности, снижение убытков за счет реализации различных категорий рисков.

# %% [markdown]
# ## 15. Модель угроз (безопасности информации), основные направления использования МУ
#
# **Модель угроз (безопасности информации)** – физическое, математическое, описательное представление свойств или характеристик угроз безопасности информации.
#
# **Модель угроз – документ, использующийся для**:
# - анализа защищенности АС, и обрабатываемой в них информации в частности, в ходе организации и выполнения работ по обеспечению безопасности информации;
# - разработки системы защиты АС, обеспечивающей нейтрализацию предполагаемых актуальных угроз безопасности информации, за счет применения соответствующих методов и способов защиты информации, с учетом данных о классе информации;
# - проведения мероприятий, направленных на предотвращение несанкционированного доступа (НСД) к информации и (или) передачи ее лицам, не имеющим права доступа к ним;
# - недопущения воздействия на технические средства АС, в результате которого может быть нарушено их функционирование;
# - контроля обеспечения уровня защищенности информации.

# %% [markdown]
# ## 16. Нарушитель, модель нарушителя, типы нарушителей
#
# **Нарушитель** – субъект, действия которого нарушают безопасность информации в конкретной АС.
#
# **Модель нарушителя** – часть модели угроз безопасности, содержащая:
# - типы, виды и потенциал нарушителей, которые могут обеспечить реализацию угроз безопасности информации;
# - цели, которые могут преследовать нарушители каждого вида при реализации угроз безопасности информации;
# - возможные способы реализации угроз безопасности информации.
#
# ### Типы нарушителей
#
# **Внешние нарушители** – лица, не имеющие права доступа к информационной системе, ее отдельным компонентам и реализующие угрозы безопасности информации из-за границ информационной системы;
#
# **Внутренние нарушители** – лица, имеющие право постоянного или разового доступа к информационной системе, ее отдельным компонентам.

# %% [markdown]
# ## 17. Потенциал нарушителя, сговор нарушителей, доверенный пользователь
#
# Возможности каждого вида нарушителя по реализации угроз безопасности информации характеризуются его **потенциалом**. **Потенциал нарушителя** определяется компетентностью, ресурсами и мотивацией, требуемыми для реализации угроз безопасности информации в информационной системе с заданными структурно функциональными характеристиками и особенностями функционирования
#
# **Сговор нарушителей** – объединенные действия нарушителей разных видов с целью повышения совокупного потенциала.
#
# В зависимости от потенциала, требуемого для реализации угроз безопасности информации, нарушители подразделяются на:
# - нарушителей, обладающих **базовым (низким) потенциалом нападения** при реализации угроз безопасности информации в информационной системе;
# - нарушителей, обладающих **базовым повышенным (средним) потенциалом нападения** при реализации угроз безопасности информации в информационной системе;
# - нарушителей, обладающих **высоким потенциалом нападения** при реализации угроз безопасности информации в информационной системе.
#
# **Доверенным** является пользователь, для которого попытки реализации угроз и осуществления НСД к ресурсам АС являются маловероятными. Защита от нарушений информационной безопасности доверенным пользователем должна осуществляться организационными и правовыми мерами.
#
# ![](sa1_media/tabusers.png)

# %% [markdown]
# ## 18. Определение актуальных угроз, вероятностью реализации угрозы ИБ, проектная защищенность ИС, уровень проектной защищенности
#
# Возможные способы реализации угроз безопасности информации зависят от структурно-функциональных характеристик и особенностей функционирования информационной системы
#
# Угрозы безопасности информации могут быть реализованы нарушителями за счет:
# - несанкционированного доступа и (или) воздействия на объекты на аппаратном уровне (программы (микропрограммы), «прошитые» в аппаратных компонентах (чипсетах))
# - несанкционированного доступа и (или) воздействия на объекты на общесистемном уровне (базовые системы ввода-вывода, гипервизоры, операционные системы);
# - несанкционированного доступа и (или) воздействия на объекты на прикладном уровне (системы управления базами данных, браузеры, web-приложения, иные прикладные программы общего и специального назначения);
# - несанкционированного доступа и (или) воздействия на объекты на сетевом уровне (сетевое оборудование, сетевые приложения, сервисы);
# - несанкционированного физического доступа и (или) воздействия на линии, (каналы) связи, технические средства, машинные носители информации;
# - воздействия на пользователей, администраторов безопасности, администраторов информационной системы или обслуживающий персонал (социальная инженерия)
#
# ![](sa1_media/ugrozi.png)
#
# ### Определение актуальных угроз
#
# 1. Оценка вероятности (возможности) реализации угрозы безопасности информации
#
# >Под **вероятностью** реализации угрозы безопасности информации понимается определяемый экспертным путем показатель, характеризующий, насколько вероятным является реализация j-ой угрозы безопасности информации в информационной системе с заданными структурно-функциональными характеристиками и особенностями функционирования.
#
# При определении угроз безопасности информации на этапе создания информационной системы в случае, когда меры защиты информации не реализованы или не проведена оценка их достаточности и эффективности, оценка возможности реализации j-ой угрозы безопасности информации проводится относительно уровня **проектной защищенности информационной системы**
#
# Под **уровнем проектной защищенности** понимается исходная защищенность информационной системы, обусловленная заданными при проектировании структурно-функциональными характеристиками и условиями ее функционирования.

# %% [markdown]
# ## 19. Оценка степени возможного ущерба
#
# Для **оценки степени возможного ущерба** от реализации угрозы безопасности информации определяются возможный результат реализации угрозы безопасности информации в информационной системе, вид ущерба, к которому может привести реализация угрозы безопасности информации, степень последствий от реализации угрозы безопасности информации для каждого вида ущерба.
#
# В качестве результата реализации угрозы безопасности информации рассматриваются непосредственное или опосредованное воздействие на конфиденциальность, целостность, доступность информации, содержащейся в информационной системе.

# %% [markdown]
# ## 20. Непосредственное воздействие, опосредованное воздействие
#
# **Непосредственное воздействие** на конфиденциальность, целостность, доступность информации возможно в результате реализации **прямой** угрозы безопасности информации.
#
# **Опосредованное воздействие** на конфиденциальность, целостность, доступность информации рассматривается в результате реализации косвенных угроз безопасности информации. Реализация косвенных угроз безопасности информации **не приводит непосредственно к воздействию на КЦД** информации, но создает условия для реализации одной или нескольких прямых угроз безопасности информации, позволяющих реализовать такое воздействие.
#
# Итоговая степень возможного ущерба устанавливается по **наивысшим** значениям степени возможного ущерба, определенным для конфиденциальности, целостности, доступности информации каждого вида информации применительно к каждому виду ущерба.
